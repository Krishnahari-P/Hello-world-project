# %%
import random

comp_wins = 0
player_wins = 0
def choose_option():
    user_choice = input("Choose Rock, Paper or Scissor ")
    if user_choice in ["ROCK", "rock", "r", "R"]:
        user_choice = "r"
    elif user_choice in ["PAPER", "paper", "p", "P"]:
        user_choice = "p"
    elif user_choice in ["SCISSOR", "scissor", "s", "S"]:
        user_choice = "s"
    else: 
        print("I don't understand try again.")
        choose_option()
    return user_choice

def Computer_Option():
    comp_choice = random.randint(1,3)
    if comp_choice == 1:
        comp_choice = "r"
    elif comp_choice == 2:
        comp_choice =="p"
    else:
        comp_choice = "s"
    return comp_choice

while True:
    print("")
    user_choice = choose_option()
    comp_choice = Computer_Option()
    print("")

    if user_choice == "r":
       if comp_choice == "r":
         print("You choose rock and computer choose rock. Match tied.")
       elif comp_choice == "p":
         print("You choose rock and computer choose paper. You lose.")
         comp_wins += 1
       elif comp_choice == "s":
         print("You choose rock and computer choose scissor.You win.")
         player_wins += 1

    elif user_choice == "p":
       if comp_choice == "r":
         print("You choose paper and computer choose rock. You win.")
         player_wins += 1
       elif comp_choice == "p":
         print("You choose paper and computer choose paper. Match tied.")
       elif comp_choice == "s":
         print("You choose paper and computer choose scissor.You lose.")
         comp_wins += 1

    elif user_choice == "s":
       if comp_choice == "r":
         print("You choose scissor and computer choose rock.You lose")
         comp_wins += 1
       elif comp_choice == "p":
         print("You choose scisssor ans computer choose paper.You win.")
         player_wins += 1
       elif comp_choice == "s":
         print("You choose scissor and computer choose scissor. Match tied.")

    print("")
    print("player wins: " + str(player_wins))
    print("computer wins: " + str(comp_wins))
    print("")

    user_choice = input("Do you want to play again? (y/n)")
    if user_choice in ["YES", "yes", "y", "Y"]:
        pass
    elif user_choice in ["NO", "no", "n", "N"]:
        break
    else:
        break
# Out:
# Choose Rock, Paper or Scissor p
#
# You choose paper and computer choose rock. You win.
#
# player wins: 1
# computer wins: 0
#
# Do you want to play again? (y/n)y
#
# Choose Rock, Paper or Scissor 1
# I don't understand try again.
# Choose Rock, Paper or Scissor r
#
#
# player wins: 1
# computer wins: 0
#
# Do you want to play again? (y/n)y
#
# Choose Rock, Paper or Scissor s
#
# You choose scissor and computer choose rock.You lose
#
# player wins: 1
# computer wins: 1
#
# Do you want to play again? (y/n)n
